# %%
import numpy as np
import pandas as pd
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
datitos0 = pd.read_csv("Datos_Vega.csv",nrows=100000, encoding = "ISO-8859-1", engine='python', sep=";")

# %%
datitos0.head()
# Out:
#                        NROTARJETA MODO JURISDICCION  \
# 0  7E3D75678B9506DDB9BA6459BC8700  COL    MUNICIPAL
# 1                             NaN  COL    MUNICIPAL
# 2                             NaN  COL    MUNICIPAL
# 3                             NaN  COL    MUNICIPAL
# 4                             NaN  COL    MUNICIPAL
#
#                          ENTIDAD            LINEA  RAMAL  \
# 0  EMPRESA NUEVE DE JULIO S.A.T.  BSAS_LINEA_561B  561BA
# 1  EMPRESA NUEVE DE JULIO S.A.T.  BSAS_LINEA_561B  561BA
# 2  EMPRESA NUEVE DE JULIO S.A.T.  BSAS_LINEA_561B  561BA
# 3  EMPRESA NUEVE DE JULIO S.A.T.  BSAS_LINEA_561B  561BA
# 4  EMPRESA NUEVE DE JULIO S.A.T.  BSAS_LINEA_561B  561BA
#
#                 INTERNO       TIPO_TARIFA  CODIGOCONTRATO MOTIVO_ATS SEXO  \
# 0  0C14D0A20466B9E62B8C  Tarifa_desc_ATSF             621        AUH    F
# 1  0C14D0A20466B9E62B8C  Tarifa_desc_ATSF             621        NaN    M
# 2  0C14D0A20466B9E62B8C     Tarifa_normal             602        NaN  NaN
# ...

# %%
datitos0.filter()

# %%
datitos0.columns
# Out:
# Index(['NROTARJETA', 'MODO', 'JURISDICCION', 'ENTIDAD', 'LINEA', 'RAMAL',
#        'INTERNO', 'TIPO_TARIFA', 'CODIGOCONTRATO', 'MOTIVO_ATS', 'SEXO',
#        'LONGITUD', 'LATITUD', 'FECHA_HORA', 'ORDEN_TRX'],
#       dtype='object')

# %%
set(datitos["NROTARJETA"])
# Out:
# {nan,
#  '153DC8D266CCE6A121F8CFD91CB29D',
#  '6380B60B4745F6C412AFA9FC14DA9E',
#  '9980776AF79C9F742A3766C09E7F8D',
#  '8CFF3AC41AE9941BF97445124F808A',
#  'F0B113E821314316B4802E954B0ECF',
#  '7289E9A29F97DD0540EA4E57ABFD33',
#  '0E7743522F83675F92B26D34F8D195',
#  'C0AFC2414FC568F4743EDAFDFF57B8',
#  'EF4EF3CCE7A5FE65D877FB6702A1F3',
#  '5A58A0A74B8FCFF41E85642B693F33',
#  '31BD4B230F342DDD8714C600642927',
#  'B494824519E1ABCF22EE0D3F3A89A2',
#  '33FB24E50034672B464537BD41D181',
#  '665D8C99188F06DC3548B0AE1EF8B2',
#  'B27562C3920DDBE528DD0A5FFE7DE3',
#  '2DF0F3C3DD6FDB617E72EC290545B3',
#  '7C0B0F8DED8F7CE881BEB76BE57C4C',
#  '804D52F35039428CA14244779B9359',
#  'E7D6B546D22987CA1E300B22289F86',
#  'BFD2069041800E8E79E7DCDDF71FDB',
#  'F98B71E99839F57CE816C4431464FA',
#  '07C91CC90E1765ACEC87C2CDE6908E',
#  'E7B09908A97EFF59DFF68F75A483D7',
#  '3B82062117CB3D77B6D413DFA45130',
#  '3B1A381951CFFB8D5B774C5C94FBD9',
#  'EC83A18139C09F5D41ABC972ABD353',
# ...

# %%
from tqdm import tqdm
indices = []
for ind,k in enumerate(tqdm(range(1000))):
    if len(datitos0[datitos0["NROTARJETA"] == list(set(datitos0["NROTARJETA"]))[ind]]) > 1:
        indices.append(ind)
# Out:
# 100%|██████████| 1000/1000 [00:26<00:00, 38.35it/s]

# %%
pd.DataFrame(datitos0.iloc[indices]).transpose()
# Out:
#                                           4                              6    \
# NROTARJETA                                NaN                            NaN
# MODO                                      COL                            COL
# JURISDICCION                        MUNICIPAL                      MUNICIPAL
# ENTIDAD         EMPRESA NUEVE DE JULIO S.A.T.  EMPRESA NUEVE DE JULIO S.A.T.
# LINEA                         BSAS_LINEA_561B                BSAS_LINEA_561B
# RAMAL                                   561BA                          561BA
# INTERNO                  0C14D0A20466B9E62B8C           0C14D0A20466B9E62B8C
# TIPO_TARIFA                  Tarifa_desc_ATSF                  Tarifa_normal
# CODIGOCONTRATO                            621                            602
# MOTIVO_ATS                                AUH                            NaN
# SEXO                                        F                              F
# ...

# %%
datitos0["MOTIVO_ATS"].describe()
# Out:
# count     38962
# unique       11
# top         AUH
# freq      12524
# Name: MOTIVO_ATS, dtype: object

# %%
datitos1 = pd.read_csv("Datos_Vega1.csv",nrows=100000, encoding = "ISO-8859-1", engine='python', sep=";")

# %%
datitos1.head(25)
# Out:
#                         NROTARJETA MODO JURISDICCION  \
# 0   7E3D75678B9506DDB9BA6459BC8700  COL    MUNICIPAL
# 1                              NaN  COL    MUNICIPAL
# 2                              NaN  COL    MUNICIPAL
# 3                              NaN  COL    MUNICIPAL
# 4                              NaN  COL    MUNICIPAL
# 5                              NaN  COL    MUNICIPAL
# 6                              NaN  COL    MUNICIPAL
# 7                              NaN  COL    MUNICIPAL
# 8   7387671B2311D9F828A9848CA69AB3  COL    MUNICIPAL
# 9   1CDA7C780884D9A23461A06E6CC2DC  COL    MUNICIPAL
# 10                             NaN  COL    MUNICIPAL
# 11  98C8DACAB3C20A9272EFB701A117C0  COL    MUNICIPAL
# 12                             NaN  COL    MUNICIPAL
# 13  6FEEC629D612208CA22AC160FA663B  COL    MUNICIPAL
# 14  2D8D1DF1619B8F44FC1ACEF0F3DC33  COL    MUNICIPAL
# 15  C3576AA230551329950BA0BE5F082B  COL    MUNICIPAL
# 16                             NaN  COL    MUNICIPAL
# ...

# %%
import networkx as nx
import osmnx as ox

# %%
G = ox.graph_from_place("La Plata", network_type="walk")

# %%
G.nodes[list(G.nodes)[0]]
# Out:
# {'y': -34.91677, 'x': -57.9204624, 'street_count': 3}

# %%
ox.plot_graph(G)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
datitos0["FECHA_HORA"][10][6:10]
# Out:
# '2019'

# %%
datitos0
# Out:
#                            NROTARJETA MODO JURISDICCION  \
# 0      7E3D75678B9506DDB9BA6459BC8700  COL    MUNICIPAL
# 1                                 NaN  COL    MUNICIPAL
# 2                                 NaN  COL    MUNICIPAL
# 3                                 NaN  COL    MUNICIPAL
# 4                                 NaN  COL    MUNICIPAL
# ...                               ...  ...          ...
# 99995  3DFB6B746A7CD9560036A4E3E80A11  TRE     NACIONAL
# 99996  3DB8A73E786A938D11F3C797C3419E  TRE     NACIONAL
# 99997  9175AD2544214DF44E7F6847286383  TRE     NACIONAL
# 99998  DE82F678B360C1840E4E3CE965B1F6  TRE     NACIONAL
# 99999  573D37479997EA2F4F3BAD9F8C1FBF  TRE     NACIONAL
#
#                              ENTIDAD            LINEA     RAMAL  \
# 0      EMPRESA NUEVE DE JULIO S.A.T.  BSAS_LINEA_561B     561BA
# 1      EMPRESA NUEVE DE JULIO S.A.T.  BSAS_LINEA_561B     561BA
# 2      EMPRESA NUEVE DE JULIO S.A.T.  BSAS_LINEA_561B     561BA
# ...

# %%
datitos1
# Out:
#                            NROTARJETA MODO JURISDICCION  \
# 0      7E3D75678B9506DDB9BA6459BC8700  COL    MUNICIPAL
# 1                                 NaN  COL    MUNICIPAL
# 2                                 NaN  COL    MUNICIPAL
# 3                                 NaN  COL    MUNICIPAL
# 4                                 NaN  COL    MUNICIPAL
# ...                               ...  ...          ...
# 99995  3DFB6B746A7CD9560036A4E3E80A11  TRE     NACIONAL
# 99996  3DB8A73E786A938D11F3C797C3419E  TRE     NACIONAL
# 99997  9175AD2544214DF44E7F6847286383  TRE     NACIONAL
# 99998  DE82F678B360C1840E4E3CE965B1F6  TRE     NACIONAL
# 99999  573D37479997EA2F4F3BAD9F8C1FBF  TRE     NACIONAL
#
#                              ENTIDAD            LINEA     RAMAL  \
# 0      EMPRESA NUEVE DE JULIO S.A.T.  BSAS_LINEA_561B     561BA
# 1      EMPRESA NUEVE DE JULIO S.A.T.  BSAS_LINEA_561B     561BA
# 2      EMPRESA NUEVE DE JULIO S.A.T.  BSAS_LINEA_561B     561BA
# ...

# %%
import dask.dataframe as dd

# %%
df = dd.read_csv("Datos_Vega.csv",encoding = "ISO-8859-1", sep=";")

# %%
df
# Out:
# Dask DataFrame Structure:
#                 NROTARJETA    MODO JURISDICCION ENTIDAD   LINEA   RAMAL INTERNO TIPO_TARIFA CODIGOCONTRATO MOTIVO_ATS    SEXO LONGITUD  LATITUD FECHA_HORA ORDEN_TRX
# npartitions=767
#                     object  object       object  object  object  object  object      object          int64     object  object  float64  float64     object   float64
#                        ...     ...          ...     ...     ...     ...     ...         ...            ...        ...     ...      ...      ...        ...       ...
# ...                    ...     ...          ...     ...     ...     ...     ...         ...            ...        ...     ...      ...      ...        ...       ...
#                        ...     ...          ...     ...     ...     ...     ...         ...            ...        ...     ...      ...      ...        ...       ...
# ...

# %%
susu =df.isnull().sum()

# %%
from dask.diagnostics import ProgressBar

# %%
df.divisions
# Out:
# (None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...
