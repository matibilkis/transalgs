# %%
import dask.dataframe as dd
from dask.diagnostics import ProgressBar
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from tqdm import tqdm

import networkx as nx
import osmnx as ox
ox.config(log_console=True)
from IPython.display import IFrame
import os

# %%
df = pd.read_parquet("datos_SUBE/month_sorted/part.0.parquet")

# %%
df0 = df[df["RAMAL"] == list(set(df["RAMAL"]))[0]]

# %%
Gdrive = ox.io.load_graphml("graph_data/drive")

# %%
m1 = ox.plot_graph_folium(Gdrive, popup_attribute="name", weight=2, color="#8b0000", alpha=0.6)
# save as html file then display map as an iframe
os.makedirs("data_map_plots",exist_ok=True)
filepath = "data_map_plots/graph.html"
m1.save(filepath)
IFrame(filepath, width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="data_map_plots/graph.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import pandas as pd
draw = df0.loc[pd.Timestamp(2019,1,30)]

# %%
draw
# Out:
#             LONGITUD  LATITUD RAMAL HORA
# FECHA
# 2019-01-30   -58.048  -34.996  307E   14
# 2019-01-30   -58.048  -34.996  307E   14
# 2019-01-30   -58.048  -34.996  307E   14
# 2019-01-30   -58.048  -34.996  307E   14
# 2019-01-30   -58.048  -34.996  307E   14
# ...              ...      ...   ...  ...
# 2019-01-30   -57.950  -34.916  307E   18
# 2019-01-30   -57.950  -34.916  307E   18
# 2019-01-30   -57.950  -34.916  307E   18
# 2019-01-30   -57.948  -34.916  307E   19
# 2019-01-30   -57.948  -34.916  307E   19
#
# [5940 rows x 4 columns]

# %%
draw[["LATITUD","LONGITUD"]]
# Out:
#             LATITUD  LONGITUD
# FECHA
# 2019-01-30  -34.996   -58.048
# 2019-01-30  -34.996   -58.048
# 2019-01-30  -34.996   -58.048
# 2019-01-30  -34.996   -58.048
# 2019-01-30  -34.996   -58.048
# ...             ...       ...
# 2019-01-30  -34.916   -57.950
# 2019-01-30  -34.916   -57.950
# 2019-01-30  -34.916   -57.950
# 2019-01-30  -34.916   -57.948
# 2019-01-30  -34.916   -57.948
#
# [5940 rows x 2 columns]

# %%
points = draw[["LATITUD","LONGITUD"]].apply(lambda x: ox.get_nearest_node(Gdrive, x))
# Out:
# /home/cooper-cooper/.local/lib/python3.6/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /home/cooper-cooper/.local/lib/python3.6/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)

# %%
path = []
for x in draw[["LATITUD","LONGITUD"]].values[:100]:
    lat,lon = x
    path.append(ox.get_nearest_node(Gdrive, [lat,lon]))
# Out:
# /home/cooper-cooper/.local/lib/python3.6/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /home/cooper-cooper/.local/lib/python3.6/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /home/cooper-cooper/.local/lib/python3.6/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# ...

# %%
nx.shortest_path(Gdrive, path[1],path[-1])
# Out:
# [199812078,
#  253123968,
#  253398174,
#  253398173,
#  639647625,
#  253398170,
#  253398169,
#  3993956776,
#  253398159,
#  253398157,
#  253398156,
#  253398155,
#  253398154,
#  253398153,
#  253398152,
#  4856255656,
#  253398151,
#  253397928,
#  6127586040,
#  2659553878,
#  253398150,
#  253398149,
#  253398148,
#  253398147,
#  2761285447,
#  3927891698,
#  249416068,
#  249416057,
#  249416396,
#  249416924,
#  249417234,
#  249417654]

# %%
# save as html file then display map as an iframe
m11 = ox.plot_route_folium(Gdrive,nx.shortest_path(Gdrive, path[1],path[-1]) ,route_map=m1, weight=10)
os.makedirs("data_map_plots",exist_ok=True)
filepath = "data_map_plots/graph_path.html"
m11.save(filepath)
IFrame(filepath, width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="data_map_plots/graph_path.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
